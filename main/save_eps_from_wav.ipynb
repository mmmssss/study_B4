# %%
import os
import soundfile as sf
import matplotlib.pyplot as plt
import numpy as np
import IPython.display
from IPython.display import display

# %%
class_pathes = ["glassbreak", "gunshot", "babycry"]

# %%
 def save_eps(class_path, file_num, sdr=0, title=""):
    fig = plt.figure(dpi=100, figsize=(24, 4))
    plt.subplots_adjust(wspace=0.35, hspace=0.2)
    plt.rcParams["font.size"] = 20

    sn_rate = "sn-4.0"

    sep_path ="./result-k-shape/save_data-k-shape-nndsvda-mel_scale=700-700/" + sn_rate + "/separation/" + class_path + "/sep0/"
    path = "./mix_dataset/" + sn_rate + "/" + class_path + "/"
    sep_files = os.listdir(sep_path)
    files = os.listdir(path)


    audio, Fs = sf.read(path + files[file_num] + "/input.wav")
    plt.xlabel("入力音", fontname="MS Gothic")
    ax = fig.add_subplot(1, 4, 1)
    librosa.display.waveplot(audio, sr=Fs)

    audio, Fs = sf.read(sep_path + sep_files[file_num])
    ax = fig.add_subplot(1, 4, 2)
    plt.xlabel("分離音" + "(SI-SDR:" + str(sdr) + ")", fontname="MS Gothic")
    librosa.display.waveplot(audio, sr=Fs)

    audio, Fs = sf.read(path + files[file_num] + "/truth.wav")
    ax = fig.add_subplot(1, 4, 3)
    plt.xlabel("正解音", fontname="MS Gothic")
    librosa.display.waveplot(audio, sr=Fs)

    #plt.savefig(sep_files[file_num] + '.svg', bbox_inches="tight", pad_inches=0.05)

# %%
 def show_wav2(class_path, file_num, sdr=0, title=""):
    fig = plt.figure(figsize=(24, 4))
    plt.subplots_adjust(wspace=0.35, hspace=0.2)
    plt.rcParams["font.size"] = 35

    sn_rate = "sn-4.0"

    sep_path ="./result-k-shape/save_data-k-shape-nndsvda-mel_scale=700-700/" + sn_rate + "/separation/" + class_path + "/sep0/"
    path = "./mix_dataset/" + sn_rate + "/" + class_path + "/"
    sep_files = os.listdir(sep_path)
    files = os.listdir(path)


    audio, Fs = sf.read(path + files[file_num] + "/input.wav")
    ax = fig.add_subplot(1, 4, 1)
    ax.set_xticks([0, 220500, 441000])
    ax.set_xticklabels(['0', '5', '10'], fontsize='small')
    plt.ylim([-1.1, 1.1])
    plt.yticks([-1.0,0.0,1.0])
    plt.xlabel("入力音", fontname="MS Gothic")
    display(IPython.display.Audio(audio, rate=Fs))
    plt.plot(audio)
    
    audio, Fs = sf.read(path + files[file_num] + "/truth.wav")
    ax = fig.add_subplot(1, 4, 2)
    ax.set_xticks([0, 220500, 441000])
    ax.set_xticklabels(['0', '5', '10'], fontsize='small')
    plt.ylim([-1.1, 1.1])
    plt.yticks([-1.0,0.0,1.0])
    plt.title(title + "\n")
    plt.xlabel("正解音", fontname="MS Gothic")
    display(IPython.display.Audio(audio, rate=Fs))
    plt.plot(audio)

    audio, Fs = sf.read(sep_path + sep_files[file_num])
    ax = fig.add_subplot(1, 4, 3)
    ax.set_xticks([0, 220500, 441000])
    ax.set_xticklabels(['0', '5', '10'], fontsize='small')
    plt.ylim([-1.1, 1.1])
    plt.yticks([-1.0,0.0,1.0])
    plt.xlabel("分離音" + "(SI-SDR:" + str(sdr) + ")", fontname="MS Gothic")
    display(IPython.display.Audio(audio, rate=Fs))
    plt.plot(audio)



    print(sep_files[file_num])

# %%
 def show_wav3(class_path, file_num, sdr1=0, sdr2=0):
    fig = plt.figure(figsize=(24, 4))
    plt.subplots_adjust(wspace=0.35, hspace=0.2)
    plt.rcParams["font.size"] = 35

    sn_rate = "sn-4.0"

    sep_path ="./sava_data-1step-mfcc64ms-2step/" + sn_rate + "/separation/" + class_path + "/sep0/"
    path = "./mix_dataset/" + sn_rate + "/" + class_path + "/"
    sep_files = os.listdir(sep_path)
    files = os.listdir(path)


    audio, Fs = sf.read(path + files[file_num] + "/input.wav")
    ax = fig.add_subplot(1, 4, 1)
    ax.set_xticks([0, 220500, 441000])
    ax.set_xticklabels(['0', '5', '10'], fontsize='small')
    plt.ylim([-1.1, 1.1])
    plt.yticks([-1.0,0.0,1.0])
    plt.xlabel('入力音', fontname="MS Gothic")
    #plt.xlabel("time[sec]")
    display(IPython.display.Audio(audio, rate=Fs))
    plt.plot(audio)
    
    audio, Fs = sf.read(path + files[file_num] + "/truth.wav")
    ax = fig.add_subplot(1, 4, 2)
    ax.set_xticks([0, 220500, 441000])
    ax.set_xticklabels(['0', '5', '10'], fontsize='small')
    plt.ylim([-1.1, 1.1])
    plt.yticks([-1.0,0.0,1.0])
    plt.xlabel('正解音', fontname="MS Gothic")
    #plt.xlabel("time[sec]")
    display(IPython.display.Audio(audio, rate=Fs))
    plt.plot(audio)

    audio, Fs = sf.read(sep_path + sep_files[file_num])
    ax = fig.add_subplot(1, 4, 3)
    ax.set_xticks([0, 220500, 441000])
    ax.set_xticklabels(['0', '5', '10'], fontsize='small')
    plt.ylim([-1.1, 1.1])
    plt.yticks([-1.0,0.0,1.0])
    plt.title("提案手法", fontname="MS Gothic")
    #plt.xlabel("time[sec]")
    plt.xlabel( "分離音(SI-SDR:" + str(sdr1) + ")", fontname="MS Gothic")
    display(IPython.display.Audio(audio, rate=Fs))
    plt.plot(audio)

    sep_path ="./save_data-mfcc/" + sn_rate + "/separation/" + class_path + "/sep0/"
    path = "./mix_dataset/" + sn_rate + "/" + class_path + "/"
    sep_files = os.listdir(sep_path)
    files = os.listdir(path)
    
    audio, Fs = sf.read(sep_path + sep_files[file_num])
    ax = fig.add_subplot(1, 4, 4)
    ax.set_xticks([0, 220500, 441000])
    ax.set_xticklabels(['0', '5', '10'], fontsize='small')
    plt.ylim([-1.1, 1.1])
    plt.yticks([-1.0,0.0,1.0])
    plt.title("既存手法", fontname="MS Gothic")
    #plt.xlabel("time[sec]")
    plt.xlabel( "分離音(SI-SDR:" + str(sdr2) + ")", fontname="MS Gothic")
    display(IPython.display.Audio(audio, rate=Fs))
    plt.plot(audio)

# %%
fig = plt.figure(figsize=(24, 4))
plt.subplots_adjust(wspace=0.35, hspace=0.2)
plt.rcParams["font.size"] = 28

class_path = "glassbreak"
file_num = 104
#59 64
#42

sn_rate = "sn-4.0"
path = "./mix_dataset/" + sn_rate + "/" + class_path + "/"
files = os.listdir(path)
audio, Fs = sf.read(path + files[file_num] + "/input.wav")
ax = fig.add_subplot(1, 3, 1)
ax.set_xticks([0, 220500, 441000])
ax.set_xticklabels(['0', '5', '10'], fontsize='small')
plt.title("S/N:-4.0dB")
plt.xlabel("time[sec]")
plt.plot(audio)


sn_rate = "sn0.0"
path = "./mix_dataset/" + sn_rate + "/" + class_path + "/"
files = os.listdir(path)
audio, Fs = sf.read(path + files[file_num] + "/input.wav")
ax = fig.add_subplot(1, 3, 2)
ax.set_xticks([0, 220500, 441000])
ax.set_xticklabels(['0', '5', '10'], fontsize='small')
plt.title("S/N:0.0dB")
plt.xlabel("time[sec]")
plt.plot(audio)

sn_rate = "sn4.0"
path = "./mix_dataset/" + sn_rate + "/" + class_path + "/"
files = os.listdir(path)
audio, Fs = sf.read(path + files[file_num] + "/input.wav")
ax = fig.add_subplot(1, 3, 3)
ax.set_xticks([0, 220500, 441000])
ax.set_xticklabels(['0', '5', '10'], fontsize='small')
plt.title("S/N:4.0dB")
plt.xlabel("time[sec]")
plt.plot(audio)

plt.show()
